# %%
# Ssupport Vector Model

# %%
# !pip install sklearn --upgrade

# %%
# !pip install joblib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# set y values
y_raw= df['koi_disposition']

# %%
# Set features. This will also be used as your x values.
X_raw= df[[ 'koi_fpflag_nt','koi_fpflag_ss','koi_fpflag_co', 'koi_fpflag_ec','koi_period','koi_period_err1','koi_period_err2','koi_time0bk', 'koi_time0bk_err1','koi_steff_err2','koi_slogg','koi_slogg_err1','koi_slogg_err2','koi_srad','koi_srad_err1','koi_srad_err2','dec', 'ra', 'koi_kepmag']]

# %%
data = df.values
X = data[:, 1:20]
y = data[:,0]

# %%
y
# Out:
# array(['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', ..., 'CANDIDATE',
#        'FALSE POSITIVE', 'FALSE POSITIVE'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)

# %%
for label, original_class in zip(encoded_y, y):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: FALSE POSITIVE
# Encoded Label: 2
# ------------
# Original Class: CONFIRMED
# Encoded Label: 1
# ------------
# Original Class: CONFIRMED
# ...

# %%
# Split our data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, encoded_y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
y_scaler = MinMaxScaler().fit(y_train.reshape(-1,1))

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train.reshape(-1,1))
y_test_scaled = y_scaler.transform(y_test.reshape(-1,1))

# %%
len(y_train)
# Out:
# 5243

# %% [raw]
# y_train_scaled

# %%
from sklearn.svm import SVC
model2 = SVC()

# %%
model2.fit(X_train_scaled, y_train)
# Out:
# SVC()

# %%
print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.791531565897387
# Testing Data Score: 0.7980549199084668

# %%
predictions = model2.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#       Prediction  Actual
# 0              2       2
# 1              2       0
# 2              2       2
# 3              2       2
# 4              2       2
# ...          ...     ...
# 1743           2       0
# 1744           2       0
# 1745           2       1
# 1746           2       1
# 1747           2       1
#
# [1748 rows x 2 columns]

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
              'gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(model2, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ..............................C=1, gamma=0.0001; total time=   1.1s
# [CV 2/5] END ..............................C=1, gamma=0.0001; total time=   1.1s
# [CV 3/5] END ..............................C=1, gamma=0.0001; total time=   1.1s
# [CV 4/5] END ..............................C=1, gamma=0.0001; total time=   1.1s
# [CV 5/5] END ..............................C=1, gamma=0.0001; total time=   1.1s
# [CV 1/5] END ..............................C=1, gamma=0.0005; total time=   1.1s
# [CV 2/5] END ..............................C=1, gamma=0.0005; total time=   1.1s
# [CV 3/5] END ..............................C=1, gamma=0.0005; total time=   1.1s
# [CV 4/5] END ..............................C=1, gamma=0.0005; total time=   1.1s
# [CV 5/5] END ..............................C=1, gamma=0.0005; total time=   1.1s
# [CV 1/5] END ...............................C=1, gamma=0.001; total time=   1.1s
# ...

# %%
# List the best parameters for this dataset
print(grid.best_params_)
# Out:
# {'C': 50, 'gamma': 0.005}

# %%
# List the best score
print(grid.best_score_)
# Out:
# 0.7896244333025273

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)

# %%
predictions
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=["blue", "red", "yellow"]))
# Out:
#               precision    recall  f1-score   support
#
#         blue       0.00      0.00      0.00       411
#          red       0.00      0.00      0.00       484
#       yellow       0.49      1.00      0.66       853
#
#     accuracy                           0.49      1748
#    macro avg       0.16      0.33      0.22      1748
# weighted avg       0.24      0.49      0.32      1748
# C:\Users\natha\.conda\envs\PythonAdv\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
